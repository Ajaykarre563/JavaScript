# %% [markdown]
# # **what is mean by Scope?**

# %% [markdown]
# scope refers to the context in which variables are declared and accessed. It determines where variables, functions, and objects are accessible from in your code.

# %% [markdown]
# # **Types of Scope in JavaScript:**

# %% [markdown]
# # **Global Scope**
#
# Variables declared outside any function or block are in the global scope.
#
# Accessible from anywhere in your code.
#
#
#
# ```
# let name = "Alice";
#
# function greet() {
#   console.log(name); // Accessible
# }
#
# ```

# %% [markdown]
# # **Function Scope**
#
# Variables declared inside a function are only accessible within that function.
#
#
#
# ```
# function greet() {
#   let message = "Hello";
#   console.log(message); // Accessible here
# }
# console.log(message); // ❌ Error: message is not defined
#
# ```

# %% [markdown]
# # **Block Scope (introduced in ES6)**
#
# let and const are block-scoped.
#
# Variables declared inside a block {} are only accessible within that block.
#
#
#
# ```
# if (true) {
#   let age = 25;
#   console.log(age); // Accessible here
# }
# console.log(age); // ❌ Error: age is not defined
#
# ```

# %% [markdown]
# # **What is a Function?**
#
# A function is a block of code designed to perform a particular task. It runs only when you call it.

# %% [markdown]
# # **Function Declaration**

# %% [markdown]
# ```
# function greet() {
#   console.log("Hello, world!");
# }
#
# greet(); // Call the function
#
# ```

# %% [markdown]
# # **Function with Parameters and Return**

# %% [markdown]
# ```
# function add(a, b) {
#   return a + b;
# }
#
# let result = add(5, 3); // 8
# console.log(result);
#
# ```

# %% [markdown]
# # **Function Expression**

# %% [markdown]
# ```
# const multiply = function(x, y) {
#   return x * y;
# };
#
# console.log(multiply(4, 2)); // 8
#
# ```

# %% [markdown]
# # **Arrow Function (ES6+)**

# %% [markdown]
# ```
# const square = (n) => n * n;
# console.log(square(5)); // 25
#
# ```

# %% [markdown]
# More complex arrow function with multiple lines:

# %% [markdown]
# ```
# const greetUser = (name) => {
#   console.log("Hi " + name);
# };
# greetUser("Sam");
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **what is mean by JavaScript popups?**

# %% [markdown]
# # **Alert Box**
#
# Used to show a simple message to the user.
#
# Only has an OK button.

# %% [markdown]
# ```
# alert("This is an alert message!");
#
# ```

# %% [markdown]
# ```
# <html>
# <head>
# </head>
# <body>
#   <script>
#     alert("hi");
#     document.write("hello this is JS in HTML by python life");
#   </script>
# </body>
# </html>
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Confirm Box**
# Asks the user to confirm something (Yes/No or OK/Cancel).
#
# Returns true if OK is clicked, false if Cancel is clicked.

# %% [markdown]
# ```
# let result = confirm("Do you want to continue?");
# if (result) {
#   console.log("User clicked OK");
# } else {
#   console.log("User clicked Cancel");
# }
#
# ```

# %% [markdown]
# ```
# <html>
# <head>
# </head>
# <body>
#   <script>
#     var a = "welcome to JS session Please enter your name ";
#
#     var name = prompt(a); // Step 1: Ask for user's name
#
#     var b = confirm("do you want to continue"); // Step 2: Confirm with the user
#
#     document.write("hello, " + name + " this is JS in HTML by python life");
#   </script>
# </body>
# </html>
#
# ```

# %% [markdown]
# ![Screenshot 2025-04-23 173945.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-04-23 173958.png](data:image/png;base64,...)

# %% [markdown]
# # **Prompt Box**
#
# Asks the user to input something (text input).
#
# Returns the text entered or null if Cancel is clicked.

# %% [markdown]
# ```
# let name = prompt("What is your name?");
# if (name !== null) {
#   console.log("Hello, " + name + "!");
# }
#
# ```

# %% [markdown]
# ```
# <html>
# <head>
# </head>
# <body>
#   <script>
#     var a = "welcome to JS session Please enter your name ";
#
#     var name = prompt(a);
#
#     document.write("hello, " + name + " this is JS in HTML by python life");
#   </script>
# </body>
# </html>
#
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)
